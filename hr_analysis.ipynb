# %% [markdown]
# ### Diksha
# <h5> <a href = "mailto: diksharajvansh80@gmail.com"> diksharajvansh80@gmail.</a></h5>

# %% [markdown]
# <img src="https://psyliq.com/wp-content/uploads/2023/10/cropped-cropped-PSYLIQ.png" alt="Italian Trulli" width="500" height="600">

# %% [markdown]
# <div style='background-color: #87CEEB;padding-bottom:0px; color: #ffffff; border : 1px solid #000000; font-size: 25px;text-align: center; font-weight: bold; indent:'>
#  <p> <h3> HR DATA ASSESSMENT QUESTIONS</h3></p>
# </div>

# %%
# %load_ext sql
# %sql mysql+pymysql://root:admin@localhost/hr_analysis
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### 1. Retrieve the total number of employees in the dataset.

# %%
# %sql select count(*) as Total_employees from general_data;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 1 rows affected.
# [(4401,)]

# %% [markdown]
# ### 2. List all unique job roles in the dataset.

# %%
# %sql select distinct(JobRole) from general_data ;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 9 rows affected.
# [('Healthcare Representative',),
#  ('Research Scientist',),
#  ('Sales Executive',),
#  ('Human Resources',),
#  ('Research Director',),
#  ('Laboratory Technician',),
#  ('Manufacturing Director',),
#  ('Sales Representative',),
#  ('Manager',)]

# %% [markdown]
# ### 3. Find the average age of employees.

# %%
# %sql select avg(Age) as average_age from general_data;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 1 rows affected.
# [(36.920472619859126,)]

# %% [markdown]
# ### 4. Retrieve the names and ages of employees who have worked at the company for more than 5 years.

# %%
# limit has been applied only to reduce the number of rows displayed in the result.
a=%sql select Emp_name, Age, YearsAtCompany from general_data where YearsAtCompany>5 limit 10 ;
print(a)
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 10 rows affected.
# +------------------+-----+----------------+
# |     Emp_name     | Age | YearsAtCompany |
# +------------------+-----+----------------+
# | RENEE MARQUARDT  |  38 |       8        |
# |   HARVEY ELWIN   |  32 |       6        |
# |    LEON WHITE    |  46 |       7        |
# |   NATHAN HARDY   |  31 |       9        |
# | SUSAN BUCHBINDER |  25 |       6        |
# |  KIRSTEN BARASH  |  45 |       20       |
# |  DENNIS SUTTER   |  36 |       15       |
# |    JOHN BROWN    |  55 |       36       |
# |  KATHRYN BALLOU  |  47 |       10       |
# |    GRAD GREEN    |  35 |       7        |
# +------------------+-----+----------------+

# %% [markdown]
# ### 5. Get a count of employees grouped by their department.

# %%
# %%sql select Department, count(*) as No_of_Employees  from general_data
# group by Department;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 3 rows affected.
# [('Sales', 1336), ('Research & Development', 2877), ('Human Resources', 188)]

# %% [markdown]
# ### 6. List employees who have 'High' Job Satisfaction.

# %%
# %%sql select * from general_data inner join employee_survey_data on general_data.EmployeeID= employee_survey_data.EmployeeID
# where JobSatisfaction=3 limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 10 rows affected.
# [(7, 'DENNIS HERRERA', '28', 'Yes', 'Travel_Rarely', 'Research & Development', '11', '2', 'Medical', '1', 'Male', '2', 'Sales Executive', 'Single', 58130, '2', 'Y', '20', '8', 5, '2', 0, '0', '0', '1', 7, '1', '3', '1'),
#  (17, 'GEORGE FOURAS', '21', 'No', 'Travel_Rarely', 'Research & Development', '3', '2', 'Life Sciences', '1', 'Male', '1', 'Laboratory Technician', 'Single', 42130, '1', 'Y', '12', '8', 3, '3', 3, '1', '0', '3', 17, '4', '3', '4'),
#  (23, 'OLLIE BANKS', '53', 'No', 'Travel_Rarely', 'Research & Development', '11', '4', 'Life Sciences', '1', 'Female', '2', 'Research Scientist', 'Married', 21480, '3', 'Y', '11', '8', 21, '2', 5, '1', '3', '0', 23, '3', '3', '2'),
# ...

# %% [markdown]
# <h5> In the above cell limit has only been applied to reduce the number of the rows to be displayed</h5>

# %% [markdown]
# ### 7. Find the highest Monthly Income in the dataset

# %%
# %sql select max(MonthlyIncome) as highest_income from general_data;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 1 rows affected.
# [(199990,)]

# %% [markdown]
# ### 8. List employees who have 'Travel_Rarely' as their BusinessTravel type.

# %%
# %%sql select * from general_data
# where business_travel="Travel_Rarely" limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 10 rows affected.
# [(1, 'ALBERTO PEDRUCO', '51', 'No', 'Travel_Rarely', 'Sales', '6', '2', 'Life Sciences', '1', 'Female', '1', 'Healthcare Representative', 'Married', 131160, '1', 'Y', '11', '8', 1, '6', 1, '0', '0', '0'),
#  (5, 'HARVEY ELWIN', '32', 'No', 'Travel_Rarely', 'Research & Development', '10', '1', 'Medical', '1', 'Male', '1', 'Sales Executive', 'Single', 23420, '4', 'Y', '12', '8', 9, '2', 6, '0', '4', '2'),
#  (6, 'LEON WHITE', '46', 'No', 'Travel_Rarely', 'Research & Development', '8', '3', 'Life Sciences', '1', 'Female', '4', 'Research Director', 'Married', 40710, '3', 'Y', '13', '8', 28, '5', 7, '7', '7', '0'),
#  (7, 'DENNIS HERRERA', '28', 'Yes', 'Travel_Rarely', 'Research & Development', '11', '2', 'Medical', '1', 'Male', '2', 'Sales Executive', 'Single', 58130, '2', 'Y', '20', '8', 5, '2', 0, '0', '0', '1'),
# ...

# %% [markdown]
# <h5> In the above cell limit has only been applied to reduce the number of the rows to be displayed</h5>

# %% [markdown]
# ### 9. Retrieve the distinct MaritalStatus categories in the dataset.

# %%
# %sql select distinct(MaritalStatus) from general_data;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 3 rows affected.
# [('Married',), ('Single',), ('Divorced',)]

# %% [markdown]
# <h3>10. Get a list of employees with more than 2 years of work experience but less than 4 years in their current role.</h3>

# %%
# %%sql select * from general_data
# where TotalWorkingYears>2 and YearsAtCompany<4 limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 10 rows affected.
# [(7, 'DENNIS HERRERA', '28', 'Yes', 'Travel_Rarely', 'Research & Development', '11', '2', 'Medical', '1', 'Male', '2', 'Sales Executive', 'Single', 58130, '2', 'Y', '20', '8', 5, '2', 0, '0', '0', '1'),
#  (8, 'DONALD BRYANT', '29', 'No', 'Travel_Rarely', 'Research & Development', '18', '3', 'Life Sciences', '1', 'Male', '2', 'Sales Executive', 'Married', 31430, '2', 'Y', '22', '8', 10, '2', 0, '0', '0', '3'),
#  (17, 'GEORGE FOURAS', '21', 'No', 'Travel_Rarely', 'Research & Development', '3', '2', 'Life Sciences', '1', 'Male', '1', 'Laboratory Technician', 'Single', 42130, '1', 'Y', '12', '8', 3, '3', 3, '1', '0', '3'),
#  (29, 'CHRISTOPHER HAZEN', '44', 'Yes', 'Travel_Frequently', 'Research & Development', '1', '2', 'Medical', '1', 'Male', '2', 'Research Scientist', 'Divorced', 103330, '3', 'Y', '14', '8', 19, '2', 1, '0', '0', '1'),
# ...

# %% [markdown]
# <h5> In the above cell limit has only been applied to reduce the number of the rows to be displayed</h5>

# %% [markdown]
# ### 12. Find the average distance from home for employees in each department.

# %%
# %%sql select Department, round(avg(DistanceFromHome),2) as average_distance from general_data
# group by Department;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 3 rows affected.
# [('Sales', 9.23), ('Research & Development', 9.23), ('Human Resources', 8.29)]

# %% [markdown]
# ### 13. Retrieve the top 5 employees with the highest MonthlyIncome

# %%
# %%sql select * from general_data
# order by MonthlyIncome desc limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 5 rows affected.
# [(3326, 'LAWRENCE LAU', '42', 'No', 'Travel_Rarely', 'Research & Development', '18', '1', 'Technical Degree', '1', 'Female', '2', 'Research Scientist', 'Married', 199990, '2', 'Y', '23', '8', 17, '6', 5, '1', '3', '1'),
#  (386, 'KEVIN LABANOWSKI', '42', 'No', 'Travel_Rarely', 'Research & Development', '18', '1', 'Technical Degree', '1', 'Female', '2', 'Research Scientist', 'Married', 199990, '2', 'Y', '23', '8', 17, '6', 5, '1', '3', '1'),
#  (1856, 'DAVID KUCIA', '42', 'No', 'Travel_Rarely', 'Research & Development', '18', '1', 'Technical Degree', '1', 'Female', '2', 'Research Scientist', 'Married', 199990, '2', 'Y', '23', '8', 17, '6', 5, '1', '3', '1'),
#  (2412, 'NATHAN SZUTU', '36', 'No', 'Travel_Rarely', 'Research & Development', '2', '2', 'Technical Degree', '1', 'Male', '3', 'Sales Executive', 'Married', 199730, '6', 'Y', '12', '8', 10, '2', 3, '0', '2', '0'),
# ...

# %% [markdown]
# ### 14. Calculate the percentage of employees who have had a promotion in the last year.

# %%
# %%sql select round((select count(EmployeeID) from general_data where YearsSinceLastPromotion=1)/count(EmployeeID) *100,2)
#                    as Percentage from general_data;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 1 rows affected.
# [(Decimal('24.27'),)]

# %% [markdown]
# ### 15. List the employees with the highest and lowest EnvironmentSatisfaction.

# %%
# %%sql select general_data.Emp_name, general_data.EmployeeID,employee_survey_data.JobSatisfaction, employee_survey_data.EnvironmentSatisfaction
# from general_data inner join employee_survey_data
# on general_data.EmployeeID= employee_survey_data.EmployeeID
# where employee_survey_data.EnvironmentSatisfaction= (select min(EnvironmentSatisfaction) from employee_survey_data) or
#  employee_survey_data.EnvironmentSatisfaction= (select max(EnvironmentSatisfaction) from employee_survey_data) limit 10 ;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 10 rows affected.
# [('RENEE MARQUARDT', 4, '4', '4'),
#  ('HARVEY ELWIN', 5, '1', '4'),
#  ('DENNIS HERRERA', 7, '3', '1'),
#  ('DONALD BRYANT', 8, '2', '1'),
#  ('JOHN BROWN', 13, '1', '4'),
#  ('KATHRYN BALLOU', 14, '2', '1'),
#  ('DONALD FIELDS', 15, '4', '4'),
#  ('GEORGE FOURAS', 17, '3', '4'),
#  ('MARTIN LALOR JR', 18, '4', '1'),
#  ('DARCY KELLER', 20, '1', '1')]

# %% [markdown]
# <h5> In the above cell limit has only been applied to reduce the number of the rows to be displayed</h5>

# %% [markdown]
# ### 16. Find the employees who have the same JobRole and MaritalStatus.

# %%
# %%sql SELECT * FROM general_data
# WHERE (JobRole, MaritalStatus) IN (
#     SELECT JobRole, MaritalStatus
#     FROM general_data
#     GROUP BY JobRole, MaritalStatus
#     HAVING COUNT(*) > 1) limit 10;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 10 rows affected.
# [(1, 'ALBERTO PEDRUCO', '51', 'No', 'Travel_Rarely', 'Sales', '6', '2', 'Life Sciences', '1', 'Female', '1', 'Healthcare Representative', 'Married', 131160, '1', 'Y', '11', '8', 1, '6', 1, '0', '0', '0'),
#  (2, 'LAWRENCE LEE', '31', 'Yes', 'Travel_Frequently', 'Research & Development', '10', '1', 'Life Sciences', '1', 'Female', '1', 'Research Scientist', 'Single', 41890, '0', 'Y', '23', '8', 6, '3', 5, '1', '4', '1'),
#  (3, 'DWAYNE CURRY', '32', 'No', 'Travel_Frequently', 'Research & Development', '17', '4', 'Other', '1', 'Male', '4', 'Sales Executive', 'Married', 193280, '1', 'Y', '15', '8', 5, '2', 5, '0', '3', '3'),
#  (4, 'RENEE MARQUARDT', '38', 'No', 'Non-Travel', 'Research & Development', '2', '5', 'Life Sciences', '1', 'Male', '3', 'Human Resources', 'Married', 83210, '3', 'Y', '11', '8', 13, '5', 8, '7', '5', '3'),
# ...

# %% [markdown]
# <h5> In the above cell limit has only been applied to reduce the number of the rows to be displayed</h5>

# %% [markdown]
# <h3> 17. List the employees with the highest TotalWorkingYears who also have a
# PerformanceRating of 4</h3>.

# %%
# %%sql select * from general_data inner join manager_survey_data
# on general_data.EmployeeID= manager_survey_data.EmployeeID
# where general_data.TotalWorkingYears=( select max(TotalWorkingYears) from general_data)
# and manager_survey_data.PerformanceRating=4;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 0 rows affected.
# []

# %% [markdown]
# <h4>Note:</h4> There is no such employee with the highest TotalWorkingYears who also have a performance rating of 4

# %% [markdown]
# ### 18. Calculate the average Age and JobSatisfaction for each BusinessTravel type.

# %%
# %%sql select general_data.business_travel,round( Avg(general_data.Age)) as Average_age,round(avg(employee_survey_data.JobSatisfaction),2) as Average_JobSatisfaction
# from general_data inner join employee_survey_data on general_data.EmployeeID= employee_survey_data.EmployeeID
# group by general_data.business_travel;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 3 rows affected.
# [('Travel_Rarely', 37.0, 2.7),
#  ('Travel_Frequently', 36.0, 2.79),
#  ('Non-Travel', 37.0, 2.78)]

# %% [markdown]
# ### 19. Retrieve the most common EducationField among employees.

# %%
# %%sql select EducationField,count(EducationField) as count from general_data
# group by EducationField
# order by count desc limit 1 ;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 1 rows affected.
# [('Life Sciences', 1812)]

# %% [markdown]
# <h3>20. List the employees who have worked for the company the longest but haven't had a
# promotion</h3>.

# %%
# %%sql select * from general_data
# where YearsAtCompany=(select max(YearsAtCompany) from general_data) and YearsSinceLastPromotion=0;
# Out:
#  * mysql+pymysql://root:***@localhost/hr_analysis
# 0 rows affected.
# []

# %% [markdown]
# <h4> Note: There is no such employee.</h4>
